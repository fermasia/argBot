# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

import plotly
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.io as pio

init_notebook_mode(connected=True)
plotly.__version__

import os
import pickle

from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model  import LogisticRegression

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import train_test_split

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from catboost import CatBoostClassifier

from sklearn.pipeline import Pipeline
from sklearn.base import TransformerMixin
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
scraped = pd.read_pickle('../datasets/TweetsScrapedUsers_final.pkl')
original = pd.concat([pd.read_pickle('../datasets/UsersDataset_2.pkl'),\
                 pd.read_pickle('../datasets/UsersDataset_3.pkl'),\
                 pd.read_pickle('../datasets/UsersDataset_4.pkl'),\
                 pd.read_pickle('../datasets/UsersDataset_5.pkl'),\
                 pd.read_pickle('../datasets/UsersDataset_6.pkl'),\
                 pd.read_pickle('../datasets/UsersDataset_7.pkl')])
users = original[original.id.isin(scraped.user_id)]

# %%
tweets = pd.read_pickle('../datasets/tweetsProcesados.pkl')
#users = pd.read_pickle('../datasets/UsersDataset.pkl')

tweets = tweets[tweets.tweetsCount.apply(int) > 50]

users.index = users.index.map(int).values
tweets.index = tweets.index.map(int).values

print(len(users))
print(len(tweets))
display(users.head(2))
display(tweets.head(2))
# Out:
# 1577
# 1671
#                     id    screen_name     complete_name tweet_count  \
# 146431317    146431317       alitapaz               Ale      370962
# 4915730830  4915730830  Posadas_Unida  Unidad Posadeña.        1965
#
#                                                   description  \
# 146431317                                Inventamos o erramos
# 4915730830  Defensor de la cultura y de toda Posadas. Siem...
#
#                       location birthdate    url listed_count  \
# 146431317         Buenos Aires     False  False            1
# 4915730830  Posadas, Argentina     False  False            0
#
#                      created_at                  crawled_at favs_count  \
# 146431317   2010-05-01 00:00:00  2019-06-29 23:15:56.175044     260133
# 4915730830  2016-02-01 00:00:00  2019-06-29 23:16:17.191700         55
#
#            followers_count following_count verified
# 146431317             4242            4988    False
# 4915730830            4939            5407    False
#            user_id tweetsCount semanas       lun    mar       mie      jue  \
# 10012122  10012122         803       2     177.0  186.0     164.0    141.0
# 10122672  10122672         771     128  2.490566    2.0  2.068966  2.15625
#
#                vie      sab       dom  ...  num_mentions_mean  \
# 10012122      10.0    125.0       531  ...                0.0
# 10122672  2.272727  1.74359  2.242424  ...  4805.194805194805
#
#          num_mentions_median   num_mentions_std num_mentions_fq  \
# 10012122  2544.5469343526756                0.0             0.0
# 10122672                 0.0  7688.441304995766             0.0
#
#              num_mentions_tq   reply_count_mean  reply_count_median  \
# 10012122  32571.785268414485            10000.0  114786.22588505047
# 10122672             10000.0  38311.68831168831             20000.0
#
#             reply_count_std reply_count_fq reply_count_tq
# 10012122                0.0        30000.0           None
# 10122672  65167.50859297861            0.0        50000.0
#
# [2 rows x 45 columns]

# %%
completeDf = tweets.join(users, how='inner')
completeDf.head()
# Out:
#            user_id tweetsCount semanas       lun        mar        mie  \
# 10012122  10012122         803       2     177.0      186.0      164.0
# 10122672  10122672         771     128  2.490566        2.0   2.068966
# 10162502  10162502         818     100       2.7   2.210526   2.563636
# 10246422  10246422         832      26  6.565217    6.26087   5.272727
# 10283902  10283902         847       4      49.0  49.666667  50.333333
#
#                jue       vie        sab       dom  ...              location  \
# 10012122     141.0      10.0      125.0       531  ...  Londres, Inglaterra.
# 10122672   2.15625  2.272727    1.74359  2.242424  ...    Rosario, Argentina
# 10162502  2.959184  2.346154    2.03125       2.0  ...                 False
# 10246422  5.130435  5.166667        3.5  4.857143  ...               Neuquén
# 10283902      46.5     39.75  18.333333      2252  ...                 Chile
#
#                  birthdate                                      url  \
# 10012122             False                             bbcmundo.com
# 10122672  22 de septiembre                           penotti.com.ar
# 10162502             False                            miriamruiz.es
# 10246422             False  sigloxxieditores.com.ar/fichaLibro.php…
# 10283902             False                              lanacion.cl
#
#          listed_count           created_at                  crawled_at  \
# 10012122           10  2007-11-01 00:00:00  2019-06-29 23:32:57.072146
# 10122672          186  2007-11-01 00:00:00  2019-07-02 18:59:47.874537
# 10162502           25  2007-11-01 00:00:00  2019-06-30 21:29:20.733391
# 10246422            0  2007-11-01 00:00:00  2019-06-30 00:04:08.174415
# 10283902            6  2007-11-01 00:00:00  2019-07-02 18:59:54.679406
#
#          favs_count followers_count following_count verified
# 10012122        920         3141578             399     True
# 10122672      11197           56336           37916    False
# 10162502        485            1345            1001    False
# 10246422      70187           29614            7898    False
# 10283902        804          323425            4354     True
#
# [5 rows x 60 columns]

# %%
#crear clase
class twDataTransform(TransformerMixin):
    def fit(self, X, Y):
        return self
    def transform(self, X, Y=None):
        df = X
        try:
            df.loc[:, 'crawled_at'] = pd.DatetimeIndex(pd.to_datetime(df.crawled_at, utc=None)).tz_convert(tz='UTC')
            df.loc[:, 'created_at'] = pd.DatetimeIndex(pd.to_datetime(df.created_at, utc=None)).tz_convert(tz='UTC')
        except:
            try:
                df.loc[:, 'crawled_at'] = pd.DatetimeIndex(pd.to_datetime(df.crawled_at, utc=None)).tz_localize(tz='UTC')
                df.loc[:, 'created_at'] = pd.DatetimeIndex(pd.to_datetime(df.created_at, utc=None)).tz_localize(tz='UTC')
            except:
                df.loc[:, 'crawled_at'] = pd.DatetimeIndex(pd.to_datetime(df.crawled_at, utc=None)).tz_convert(tz='UTC')
                df.loc[:, 'created_at'] = pd.DatetimeIndex(pd.to_datetime(df.created_at, utc=None)).tz_convert(tz='UTC')
        account_life = df.crawled_at - df.created_at
        account_life_meses = np.round(account_life.dt.days / 30)
        account_life_meses = account_life_meses.replace(0, 1)
        account_life_semanas = np.round(account_life.dt.days / 7)
        account_life_semanas = account_life_semanas.replace(0, 1)
        numValues = ['tweet_count', 'listed_count', 'followers_count', 'following_count']
        for i in numValues:
            colName_mes = i+'_mes'
            df.loc[:,colName_mes] = df[i].astype(float) / account_life_meses

            colName_semana = i+'_semana'
            df.loc[:,colName_semana] = df[i].astype(float) / account_life_semanas
        columnas = np.concatenate(
            [[x+'_mes'] for x in numValues]
        )
        columnasTweets = np.concatenate(
            [
                [x+'_mean',x+'_median', x+'_std', x+'_fq', x+'_tq'] for x in
                ['times','timesRT','timesUser','favorite_count','retweet_count','num_mentions','reply_count']
            ]
        )
        columnas = np.concatenate([
            ['semanas', 'lun', 'mar', 'mie', 'jue', 'vie', 'sab', 'dom'],columnas,columnasTweets
        ])
        df = df[columnas]
        df = df.fillna(0)
        df = df.applymap(lambda x: np.round(float(x), 10) if np.isfinite(float(x)) else np.nan)
        df = df.fillna(0)
        return df
    
#load model
import pickle
with open('../modelo/modeloCompleto.pkl', 'rb') as m_pred:
    model = pickle.load(m_pred)

# %%
predicciones = model.predict_proba(completeDf)
predicciones = pd.DataFrame(predicciones)
predicciones.index = completeDf.index
predicciones.columns = ['Prob_Human', 'Prob_Bot']
usuarios_prob = pd.concat([predicciones['Prob_Bot'], completeDf], axis=1)

# %%
yval = []
xval = np.linspace(0,1, 300)
for i in xval:
    cantUsuarios = len(usuarios_prob[usuarios_prob['Prob_Bot']>i])
    yval.append(cantUsuarios)
trace1 = go.Scatter(
    name='Inscriptos',
    x=xval,
    y=yval,
#     line={
#         'shape': 'spline',
#         'smoothing': 0.7,
#     }
)
layout = go.Layout(
    title=go.layout.Title(
        text='Cantidad bots',
        xref='paper',
        x=0
    ),
)
fig = go.Figure(data=[trace1], layout=layout)
print(len(usuarios_prob))
iplot(fig)
# Out:
# 1564
# <div>
#
#
#             <div id="f3913786-ecf1-42b2-a590-f1eea91249aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f3913786-ecf1-42b2-a590-f1eea91249aa")) {
#                     Plotly.newPlot(
#                         'f3913786-ecf1-42b2-a590-f1eea91249aa',
#                         [{"name": "Inscriptos", "type": "scatter", "uid": "e53a502e-89ca-4bde-9b9b-c26d8e819308", "x": [0.0, 0.0033444816053511705, 0.006688963210702341, 0.010033444816053512, 0.013377926421404682, 0.016722408026755852, 0.020066889632107024, 0.023411371237458192, 0.026755852842809364, 0.030100334448160536, 0.033444816053511704, 0.03678929765886287, 0.04013377926421405, 0.043478260869565216, 0.046822742474916385, 0.05016722408026756, 0.05351170568561873, 0.056856187290969896, 0.06020066889632107, 0.06354515050167224, 0.06688963210702341, 0.07023411371237458, 0.07357859531772575, 0.07692307692307693, 0.0802675585284281, 0.08361204013377926, 0.08695652173913043, 0.0903010033444816, 0.09364548494983277, 0.09698996655518395, 0.10033444816053512, 0.10367892976588629, 0.10702341137123746, 0.11036789297658862, 0.11371237458193979, 0.11705685618729096, 0.12040133779264214, 0.12374581939799331, 0.12709030100334448, 0.13043478260869565, 0.13377926421404682, 0.13712374581939799, 0.14046822742474915, 0.14381270903010032, 0.1471571906354515, 0.1505016722408027, 0.15384615384615385, 0.15719063545150502, 0.1605351170568562, 0.16387959866220736, 0.16722408026755853, 0.1705685618729097, 0.17391304347826086, 0.17725752508361203, 0.1806020066889632, 0.18394648829431437, 0.18729096989966554, 0.1906354515050167, 0.1939799331103679, 0.19732441471571907, 0.20066889632107024, 0.2040133779264214, 0.20735785953177258, 0.21070234113712374, 0.2140468227424749, 0.21739130434782608, 0.22073578595317725, 0.22408026755852842, 0.22742474916387959, 0.23076923076923075, 0.23411371237458192, 0.23745819397993312, 0.2408026755852843, 0.24414715719063546, 0.24749163879598662, 0.2508361204013378, 0.25418060200668896, 0.25752508361204013, 0.2608695652173913, 0.26421404682274247, 0.26755852842809363, 0.2709030100334448, 0.27424749163879597, 0.27759197324414714, 0.2809364548494983, 0.2842809364548495, 0.28762541806020064, 0.2909698996655518, 0.294314381270903, 0.29765886287625415, 0.3010033444816054, 0.30434782608695654, 0.3076923076923077, 0.3110367892976589, 0.31438127090301005, 0.3177257525083612, 0.3210702341137124, 0.32441471571906355, 0.3277591973244147, 0.3311036789297659, 0.33444816053511706, 0.3377926421404682, 0.3411371237458194, 0.34448160535117056, 0.34782608695652173, 0.3511705685618729, 0.35451505016722407, 0.35785953177257523, 0.3612040133779264, 0.36454849498327757, 0.36789297658862874, 0.3712374581939799, 0.3745819397993311, 0.37792642140468224, 0.3812709030100334, 0.3846153846153846, 0.3879598662207358, 0.391304347826087, 0.39464882943143814, 0.3979933110367893, 0.4013377926421405, 0.40468227424749165, 0.4080267558528428, 0.411371237458194, 0.41471571906354515, 0.4180602006688963, 0.4214046822742475, 0.42474916387959866, 0.4280936454849498, 0.431438127090301, 0.43478260869565216, 0.43812709030100333, 0.4414715719063545, 0.44481605351170567, 0.44816053511705684, 0.451505016722408, 0.45484949832775917, 0.45819397993311034, 0.4615384615384615, 0.4648829431438127, 0.46822742474916385, 0.47157190635451507, 0.47491638795986624, 0.4782608695652174, 0.4816053511705686, 0.48494983277591974, 0.4882943143812709, 0.4916387959866221, 0.49498327759197325, 0.4983277591973244, 0.5016722408026756, 0.5050167224080268, 0.5083612040133779, 0.5117056856187291, 0.5150501672240803, 0.5183946488294314, 0.5217391304347826, 0.5250836120401338, 0.5284280936454849, 0.5317725752508361, 0.5351170568561873, 0.5384615384615384, 0.5418060200668896, 0.5451505016722408, 0.5484949832775919, 0.5518394648829431, 0.5551839464882943, 0.5585284280936454, 0.5618729096989966, 0.5652173913043478, 0.568561872909699, 0.5719063545150501, 0.5752508361204013, 0.5785953177257525, 0.5819397993311036, 0.5852842809364548, 0.588628762541806, 0.5919732441471571, 0.5953177257525083, 0.5986622073578595, 0.6020066889632107, 0.6053511705685619, 0.6086956521739131, 0.6120401337792643, 0.6153846153846154, 0.6187290969899666, 0.6220735785953178, 0.6254180602006689, 0.6287625418060201, 0.6321070234 ...

# %%
probaFilter = .7
print(len(usuarios_prob[usuarios_prob.Prob_Bot > probaFilter]) / len(usuarios_prob) * 100)
usuarios_prob[usuarios_prob.Prob_Bot > probaFilter].sort_values('Prob_Bot', ascending=False)[['Prob_Bot','screen_name','complete_name','tweet_count','description']]
# Out:
# 5.818414322250639
#                     Prob_Bot      screen_name              complete_name  \
# 1658740507          0.989592   twitpoliticoOK              twit político
# 827352011595194368  0.987680        QuorumARG             Quorum Digital
# 783129248           0.976391     Federico2015        Justicia y Libertad
# 771243914           0.965900   Winifreda_Noti         Winifreda La Pampa
# 461714626           0.954018    soywashington           Washington Party
# 7848912             0.950499        abc_gente               Gente en ABC
# 8173372             0.940797        vinchusky             Very Hinchusky
# 1455253418          0.936993         TVCanalC            Canal C Córdoba
# 8973622             0.936785  InfobaeEconomia           Infobae Economía
# 2246294855          0.932285          _Nango_                  N A N G O
# 2236552801          0.930844     Brian35River            Brian Moreno  🐃
# 517682344           0.910409        INFOen140               INFOen140  🌐
# 752871176637153280  0.909707       Flantasma1                  flantasma
# 436814099           0.909698  PalmiroCaballas  150 DE FIAMBRIN FERNANDEZ
# 259935555           0.905212       iFutboler0           Samuel Alejandro
# 8973802             0.903226  InfobaePolitica           Infobae Política
# 758359163760218112  0.895829          bizerok                          💥
# 126964101           0.895015         hf183896        Hugo Jorge Fornillo
# 764929812           0.878089     AntoBourlot_                      αη  ☘
# 1700125574          0.870458         ezerojo9                ᴇᴢᴇǫᴜɪᴇʟ  ⚓
# 733783186157625345  0.869459           gus_bs         Guru  AFRI-K~NO !!
# 822680268058333184  0.866856  frenandodelarua            frenandodelarua
# 780608929           0.865098      Tomi_delrio             Tomi del Rio ♛
# 128414324           0.862767     SUKOICRIOLLO          LEONER CRIOLLO G.
# 3492426316          0.857957  NahuelRiquelme_             Riquelmista  ⚽
# 17924680            0.847747    aguilasultana               Lewis Itfish
# 461707113           0.843418      SoyYoCELEST             ƇƐĿƐSƬƐ. 💙 💛 💙
# 2285275704          0.838604   EmpresarialARG          Mundo Empresarial
# 709749375904440320  0.836008      alejand1522         TomHagenParaPobres
# 244762084           0.835924   distanceplayer                          -
# ...                      ...              ...                        ...
# 1410380994          0.767691    EAristeguieta       Enrique Aristeguieta
# 3946571             0.766683   diazvillanueva            Díaz Villanueva
# 266572982           0.765921     Crisdeteatro                   Cristina
# 147004073           0.764034     xpiliahumada           pilar ahumada ⚡️
# 1679810774          0.758265    SoyElTioWilly                Willy Ruano
# 4085391196          0.749196   bollo_patricia            PATRICIA BOLLO.
# 753000988215238657  0.748299        kookfancy                       vico
# 1688030911          0.746876         hyunjace                    gildan.
# 756369512530866177  0.741188      killmankind                       mila
# 4905223479          0.739305       magoya2001                    Roberto
# 911069238           0.738933     CitasMelendi            Frases Melendi®
# 1558617428          0.735537        KatzMario                 Mario Katz
# 731728730           0.734049    mariancarbone                       iaio
# 1684410456          0.731065    maestroyoda56               Maestro Yoda
# 764650614           0.726458  correasantiago_            Santiago Correa
# 146197092           0.726095    Juansistemico            Juan sin Nombre
# 4122547169          0.717664         TersPepe               Pepe El Ters
# 3621289273          0.715167  SalvaPresidente          Salvador Nasralla
# 728075232011915266  0.714329    PasaEseFasito     ᴸ    ᴵ    ᴬ    ᴹ     🍁
# 1681793366          0.714116        zulania55                     zula 💙
# 1361984828          0.709346     electo_mania                electomania
# 115702781           0.707168      LishoOvalle                    Mapache
# 8974082             0.706564      TeleShowcom                   TeleShow
# 538448481           0.705587    justiciacerca           Justicia Córdoba
# 13556382            0.704855   EnriqueVasquez            Enrique Vásquez
# 94258247            0.704336         JIKobryn        Juan Ignacio Kobryn
# 774720260           0.703926        juan_dpdp         Sustrato Peronista
# 752562450613014528  0.702728   AllenDullesCIA        TiremosDelCarroDeMM
# 765966868045848576  0.701035       pow_luengo               Pablo Luengo
# 219788847           0.700990       ElIslandes       Con CFK estaba mejor
#
#                    tweet_count  \
# 1658740507                4777
# 827352011595194368        1334
# 783129248                 9059
# 771243914                15799
# 461714626               115998
# 7848912                  37889
# 8173372                  28416
# 1455253418               23783
# 8973622                  28686
# 2246294855               19733
# 2236552801               12739
# 517682344               266481
# 752871176637153280        5800
# 436814099                10737
# 259935555                18308
# 8973802                  39949
# 758359163760218112       12781
# 126964101                30478
# 764929812                28421
# 1700125574               10596
# 733783186157625345       18432
# 822680268058333184        4356
# 780608929                32545
# 128414324                38314
# 3492426316                2404
# 17924680                 36119
# 461707113               103172
# 2285275704               21101
# 709749375904440320        3132
# 244762084                49814
# ...                        ...
# 1410380994               22878
# 3946571                  20110
# 266572982                 8049
# 147004073                63458
# 1679810774               18874
# 4085391196                2211
# 753000988215238657       62093
# 1688030911               24358
# 756369512530866177        8300
# 4905223479               23382
# 911069238                 1860
# 1558617428               12917
# 731728730                48459
# 1684410456               42424
# 764650614                81157
# 146197092                70943
# 4122547169               30199
# 3621289273                9491
# 728075232011915266       21502
# 1681793366               35484
# 1361984828               15965
# 115702781                28622
# 8974082                 150286
# 538448481                 2355
# 13556382                390396
# 94258247                  9438
# 774720260                10181
# 752562450613014528        6885
# 765966868045848576        1747
# 219788847               199841
#
#                                                           description
# 1658740507          Todas las noticias que buscás están en http://...
# 827352011595194368  Portal de noticias y actualidad del Conurbano ...
# 783129248           Soy un Argentino que me interesa saber a quien...
# 771243914           Noticias de la localidad de Winifreda , provin...
# 461714626           CANTANTE - ESCRITOR - PRODUCTOR - ARTISTA - EM...
# 7848912             Noticias de la secciones Estilo, Gente y Moda ...
# 8173372                    Tomá, pa' los chicles. Y guardá el vuelto.
# 1455253418          Cuenta oficial de Canal C Córdoba. En el 7 de ...
# 8973622             Todo el tiempo. Todas las noticias de economía...
# 2246294855          Cine - Series - Misceláneas (?) - Cuervo. Fan ...
# 2236552801          Le gané 2 finales en 1 año a mi eterno rival. ...
# 517682344           Noticias en redes sociales todo el día, todos ...
# 752871176637153280                             me gustan los perritos
# 436814099           Tropas Kurdas tomaron Ginebra. Me dicen Janis ...
# 259935555                                        ladillao desde el 95
# 8973802             Todo el tiempo. Todas las noticias de la polít...
# 758359163760218112                                               Cuak
# 126964101           Ciudadano argentino que se resiste con las arm...
# 764929812                               22. recepcionista  marketing
# 1700125574          • ᴘʀɪᴍᴇʀᴏ ʀɪᴠᴇʀ, ᴅᴇsᴘᴜᴇs ᴛᴀᴍʙɪᴇɴ  • ɢᴇᴍɪɴɪᴀɴᴏ ...
# 733783186157625345  GORILA de NACIMIENTO. MÉDICO de PROFESIÓN, Gur...
# 822680268058333184                           Sarmiento del Siglo XXI.
# 780608929                   La música es ARTE. 21 años IG: tomidelrio
# 128414324           Periodista; dejar quieto lo que está quieto, N...
# 3492426316                                             Boca- Riquelme
# 17924680
# 461707113           Me dejaron sola 5´y me hice una cuenta en #Twi...
# 2285275704          La voz de las pymes economía, política e Infor...
# 709749375904440320  Maestro de pié criando pichones blancos, que m...
# 244762084                                          hits from the bong
# ...                                                               ...
# 1410380994          Abogado (UCV) Dr. en Derecho (UC) egresado de ...
# 3946571                          La ContraCrónica | La ContraHistoria
# 266572982                                 QUE TENGAS UN BUEN DIA !!!!
# 147004073
# 1679810774          No soy creyente ni ateo y menos indiferente.  ...
# 4085391196          Lic en Marketing,  Docente, Fotógrafa. Volunta...
# 753000988215238657                           stan facha, stan bangtan
# 1688030911                                  ( RP 1997 ) #이재현 The Boyz
# 756369512530866177
# 4905223479          Argentino.No me gustan los populismos,ni el co...
# 911069238           No me gusta hacer mucho caso a la gente, yo si...
# 1558617428          Arquitecto, Radical y de Boca  EDUCACIÓN PÚBLI...
# 731728730           hola q ases en mi muro ss re      linda respon...
# 1684410456
# 764650614           Soy Comunicador-Periodista  Instagram: correas...
# 146197092                         Historias de un ciego a sus cuervos
# 4122547169          Cirujano-oncólogo,médico de flia. y comunidad....
# 3621289273          Presidente Electo de Honduras 2018-2022 en Ali...
# 728075232011915266               22|| Si dios existe es un fernecito.
# 1681793366                            SIGO A TODOS LOS QUE ME SIGUEN
# 1361984828          Web independiente especializada en demoscopia....
# 115702781                   Bla bla bla        instagram: lishoovalle
# 8974082             Todas las noticias de espectáculos en un sólo ...
# 538448481           Twitter Oficial del Poder Judicial de la Provi...
# 13556382             y  hablo de España, de Venezuela. Capitalista...
# 94258247                                    Abolicionista del trabajo
# 774720260                                         Sustrato Peronista.
# 752562450613014528  De Néstor,Cristina,Perón,Evita,Chavez,Fidel,Lu...
# 765966868045848576  No se asuste, soy catalán. | Indepe & Republic...
# 219788847           Kirchnerista desde el 27/4/2003 hasta siempre....
#
# [91 rows x 5 columns]

# %%
# Drop a un archivo excel para procesar
import openpyxl
usuarios_prob[usuarios_prob.Prob_Bot > probaFilter].sort_values('Prob_Bot', ascending=False)[['Prob_Bot','screen_name','complete_name','tweet_count','description']]\
\.to_excel('../datasets/predictedbots.xlsx',index=False)
# Out:
#   File "<ipython-input-9-f111128d8be4>", line 4
#     \.to_excel('../datasets/predictedbots.xlsx',index=False)
#                                                             ^
# SyntaxError: unexpected character after line continuation character
